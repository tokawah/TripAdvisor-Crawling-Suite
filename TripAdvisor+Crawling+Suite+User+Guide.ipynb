# %% [markdown]
# # TripAdvisor Crawling Suite User Guide
#
# Kevin Jiahua Du <br />
# 14 July, 2017

# %%
import datetime
print('Last Updated: ' + str(datetime.datetime.now()))
# Out:
# Last Updated: 2017-07-14 04:30:01.661954

# %% [markdown]
# This guide will walk you through the steps of using the crawling suite to effortlessly collect hotel data from TripAdvisor, including basic hotel information, reviews, and user profiles.

# %% [markdown]
# ## Initialization
#
# First of all, we need to configure the suite to specify locations where we want to collect hotel data.
# Open `config.ini` with a text editor, and you will see something like this:
#
# > **[THREAD]** <br />
# SleepTime = 2 <br />
# SnippetThread = 3 <br />
# HotelThread = 3 <br />
# ReviewThread = 3 <br />
# UserThread = 3 <br />
# **[LOCATION]** <br />
# List = placeholder
#
# Calm down. If you have no idea what a thread is, just leave the THREAD section as it is.
# Otherwise edit accordingly `SLEEP_TIME` seconds to wait between each connection to TripAdvisor; `SNIPPET_THREAD_NUM`, `DETAIL_THREAD_NUM`, `REVIEW_THREAD_NUM`, and `USER_THREAD_NUM` the number of threads in each crawling module.
# In practice, a minimum pause of two seconds and at most three threads for each crawler are recommended.
#
# Telling the suite where to collect data is easy. The most simple way is to replace the placeholder with an URL describing a location.
# You can find the URL after you submit a query for a location on TripAdvisor. Take Melbourne, it should be:
#
# > https://www.tripadvisor.com.au/Hotels-g255100-Melbourne_Victoria-Hotels.html
#
# The placeholder is also available for multiple locations by concatenating all URLs with semicolon and no space. For example, $URL_1;URL_2;URL_3;...;URL_n$.
#
# We offer a crawling module to automatically gather all location URLs within a given area, say all cities within Victoria and even Australia.
# Once the gathering finished, the module will store the URL string in the same directory.

# %%
from crawlers import crawlLocations

area_url = 'https://www.tripadvisor.com.au/Hotels-g255098-Victoria-Hotels.html'
crawlLocations.start(area_url)
# Out:
# locations in 10 pages.
# [page 1] https://www.tripadvisor.com.au/Hotels-g255098-Victoria-Hotels.html
# [page 2] https://www.tripadvisor.com.au/Hotels-g255098-oa20-Victoria-Hotels.html
# [page 3] https://www.tripadvisor.com.au/Hotels-g255098-oa40-Victoria-Hotels.html
# [page 4] https://www.tripadvisor.com.au/Hotels-g255098-oa60-Victoria-Hotels.html
# [page 5] https://www.tripadvisor.com.au/Hotels-g255098-oa80-Victoria-Hotels.html
# [page 6] https://www.tripadvisor.com.au/Hotels-g255098-oa100-Victoria-Hotels.html
# [page 7] https://www.tripadvisor.com.au/Hotels-g255098-oa120-Victoria-Hotels.html
# [page 8] https://www.tripadvisor.com.au/Hotels-g255098-oa140-Victoria-Hotels.html
# [page 9] https://www.tripadvisor.com.au/Hotels-g255098-oa160-Victoria-Hotels.html
# [page 10] https://www.tripadvisor.com.au/Hotels-g255098-oa180-Victoria-Hotels.html
# 195 locations found.

# %% [markdown]
# Next, we need to set up a database called ta.db, and create four tables for storing locations, hotels, reviews, and reviewers with a few lines of code.

# %%
from os.path import isfile
from tadb import taDB

fn = 'ta.db'
if not isfile(fn):
    with taDB(fn) as db:
        db.create_tables()
        print('database {} created.'.format(fn))
# Out:
# database ta.db created.

# %% [markdown]
# Before we get started, we also need to turn on the event logger to record the crawling process and apply the configuration we just made to the suite.

# %%
from start import *

# Trigger the event logger.
init_logger()
# Load and set crawler parameters.
urls = load_config()
# Out:
# INFO - parameters: [0; 3; 3; 3; 5]
# INFO - 2 locations found

# %% [markdown]
# Alright, so far we have done all the preparation.
#
# ## Data Acquisition
#
# Collecting data from TripAdvisor using is straightforward: The suite traverses each URL in the location list, invoking different modules to collect and dump the correponding information in the form of raw HTML.
# Note that those four modules must be run in the shown order.
# Nevertheless, depending on the type of data required, you can always stop the procedure at any step as long as the preceding steps are completed.

# %%
import re
from crawlers import crawlSnippets
from crawlers import crawlHotels
from crawlers import crawlReviews
from crawlers import crawlUsers

# As an example, we only collect data 
# from Trawool and Mount Waverley.
for url in urls:
    gid = re.sub('\D', '', url)
    crawlSnippets.start(gid, url.strip())
    crawlHotels.start(gid)
    crawlReviews.start(gid)
    crawlUsers.start()
# Out:
# INFO - [location 552264] Trawool Victoria
# INFO - 1 hotels in 1 pages
# INFO - 0 hotels in local cache
# INFO - [page 1] https://www.tripadvisor.com.au/Hotels-g552264-Trawool_Victoria-Hotels.html?seen=0&sequence=1&geo=552264&requestingServlet=Hotels&refineForm=true&hs=&adults=2&rooms=1&o=a0&pageSize=&rad=0&dateBumped=NONE&displayedSortOrder=popularity
# INFO - 	#0, totaling 1
# INFO - [worker 2] shutting down
# INFO - [worker 3] shutting down
# INFO - [worker 1] shutting down
# INFO - all hotel ids are ready
# INFO - [hotel 660346] https://www.tripadvisor.com.au/Hotel_Review-g552264-d660346-Reviews-Comfort_Inn_Trawool-Trawool_Victoria.html
# INFO - 	[hotel 660346] 72 reviews in 15 pages
# INFO - 	[hotel 660346] [page 1] 5 reviews, totaling 5
# INFO - 	[hotel 660346] [page 2] 5 reviews, totaling 10
# INFO - 	[hotel 660346] [page 3] 5 reviews, totaling 15
# INFO - 	[hotel 660346] [page 4] 5 reviews, totaling 20
# INFO - 	[hotel 660346] [page 5] 5 reviews, totaling 25
# INFO - 	[hotel 660346] [page 6] 5 reviews, totaling 30
# INFO - 	[hotel 660346] [page 7] 5 reviews, totaling 35
# INFO - 	[hotel 660346] [page 8] 5 reviews, totaling 40
# INFO - 	[hotel 660346] [page 9] 5 reviews, totaling 45
# INFO - 	[hotel 660346] [page 10] 5 reviews, totaling 50
# INFO - 	[hotel 660346] [page 11] 5 reviews, totaling 55
# INFO - 	[hotel 660346] [page 12] 5 reviews, totaling 60
# INFO - 	[hotel 660346] [page 13] 5 reviews, totaling 65
# INFO - 	[hotel 660346] [page 14] 5 reviews, totaling 70
# INFO - 	[hotel 660346] [page 15] 2 reviews, totaling 72
# INFO - 	[hotel 660346] 72 reviews retrieved
# INFO - [worker 2] shutting down
# INFO - [worker 3] shutting down
# INFO - [worker 1] shutting down
# INFO - all review ids are ready
# INFO - 	[hotel 660346] from 1 to 72
# INFO - [worker 3] shutting down
# INFO - [worker 1] shutting down
# INFO - [worker 2] shutting down
# INFO - all reviews are ready
# INFO - retrieving users...
# INFO - 72 users found
# INFO - [user B1A5B7467678224CF6FFBD87DA7D5E66]
# INFO - [user B79A8D783CEAC3DBE4FC7AC6618DC554]
# INFO - [user BA0B5797D5A342537EB070B8EF99A793]
# INFO - [user BB274CFD1EDFBD03176807FA6CF542BA]
# INFO - [user C122BF073E12846D0372A76B7E5CF43F]
# INFO - [user C34780BD8C16A26BB79BD04EFF6637F4]
# INFO - [user C45A2291956717B567989754E111C089]
# INFO - [user C4E4F4D3630AA153F0F0D38B8DF9DF7F]
# INFO - [user C5D7BCD24820A6877AC9CF929F49482F]
# INFO - [user C7F9CCF1CADBDDE2570AED7973927704]
# INFO - [user C943E71137CCFE899F068309DF9A2DCB]
# INFO - [user CD24804E5992917D21E46C80B62A41EA]
# INFO - [user CF5BDC137D67502744A58D0A18105E57]
# INFO - [user D4003973FB5F2F4175FAB8BCAD23CD7A]
# INFO - [user DC9CA1AC54BEE97BC4F2AA051EB6CF02]
# INFO - [user DCDB40BBB398F92DBD9F6ABFE420C4B6]
# INFO - [user DF1712CA573E96625477EF4A969BB819]
# INFO - [user E0E6E07A87FEE810709097734D63CDC8]
# INFO - [user E903C4F5B4A581405AE124E12CDA28E0]
# INFO - [user E98BD2A2AFF876C71F2BE150B4E4B5F2]
# INFO - [user EDAB30A6D7E94AFBF76495113B4A839D]
# INFO - [user F26B9B8B90F2ECFE57C8AADBDA9B5D37]
# INFO - [user F423E9B7B61EA54F6D9379FD83E0606E]
# INFO - [user F9A55264CB8FFA786ADD87178D1DAD2F]
# INFO - [worker 2] shutting down
# INFO - [worker 4] shutting down
# INFO - [worker 3] shutting down
# INFO - [worker 1] shutting down
# INFO - [worker 5] shutting down
# INFO - all user ids are ready
# INFO - [location 644412] Mount Waverley Greater Melbourne Victoria
# INFO - 1 hotels in 1 pages
# INFO - 0 hotels in local cache
# INFO - [page 1] https://www.tripadvisor.com.au/Hotels-g644412-Mount_Waverley_Greater_Melbourne_Victoria-Hotels.html?seen=0&sequence=1&geo=644412&requestingServlet=Hotels&refineForm=true&hs=&adults=2&rooms=1&o=a0&pageSize=&rad=0&dateBumped=NONE&displayedSortOrder=popularity
# INFO - 	#0, totaling 1
# INFO - [worker 3] shutting down
# INFO - [worker 1] shutting down
# INFO - [worker 2] shutting down
# INFO - all hotel ids are ready
# INFO - [hotel 566124] https://www.tripadvisor.com.au/Hotel_Review-g644412-d566124-Reviews-Lang_Mews-Mount_Waverley_Greater_Melbourne_Victoria.html
# INFO - 	[hotel 566124] 1 reviews in 1 pages
# INFO - 	[hotel 566124] [page 1] 1 reviews, totaling 1
# INFO - 	[hotel 566124] 1 reviews retrieved
# INFO - [worker 2] shutting down
# INFO - [worker 1] shutting down
# INFO - [worker 3] shutting down
# INFO - all review ids are ready
# INFO - 	[hotel 566124] from 1 to 1
# INFO - [worker 2] shutting down
# INFO - [worker 3] shutting down
# INFO - [worker 1] shutting down
# INFO - all reviews are ready
# INFO - retrieving users...
# INFO - 73 users found
# INFO - [user 00488B15DF5F89809CE9B96D77FA8B42] PASSED: verified
# INFO - [user 83EAE255A3CB3B7261923F2AB68DB911] PASSED: verified
# INFO - [user 841AC2C00AF29D506951CB9678D43474] PASSED: verified
# INFO - [user 86B42A2102F20203772D0DD0EE0F5858] PASSED: verified
# INFO - [user 871E2B6D2863474AD1406839E906E19F] PASSED: verified
# INFO - [user 8C2AE9C2EBDF526C013F3C4B46A9D080] PASSED: verified
# INFO - [user 8C2E786919CBDAED72EF110B38DAA178] PASSED: verified
# INFO - [user 90F99D6B1FC3A1FD2E1AC52A97C0509E] PASSED: verified
# INFO - [user 961813041BFA0419D5880E73EAEEF9DC] PASSED: verified
# INFO - [user 9D2082EDCF3DC92961AECB77759150D2] PASSED: verified
# INFO - [user B1A5B7467678224CF6FFBD87DA7D5E66] PASSED: verified
# INFO - [user B79A8D783CEAC3DBE4FC7AC6618DC554] PASSED: verified
# INFO - [user BA0B5797D5A342537EB070B8EF99A793] PASSED: verified
# INFO - [user BB274CFD1EDFBD03176807FA6CF542BA] PASSED: verified
# INFO - [user C122BF073E12846D0372A76B7E5CF43F] PASSED: verified
# INFO - [user C34780BD8C16A26BB79BD04EFF6637F4] PASSED: verified
# INFO - [user C45A2291956717B567989754E111C089] PASSED: verified
# INFO - [user C4E4F4D3630AA153F0F0D38B8DF9DF7F] PASSED: verified
# INFO - [user C5D7BCD24820A6877AC9CF929F49482F] PASSED: verified
# INFO - [user C7F9CCF1CADBDDE2570AED7973927704] PASSED: verified
# INFO - [user C943E71137CCFE899F068309DF9A2DCB] PASSED: verified
# INFO - [user CD24804E5992917D21E46C80B62A41EA] PASSED: verified
# INFO - [user CF5BDC137D67502744A58D0A18105E57] PASSED: verified
# INFO - [user D4003973FB5F2F4175FAB8BCAD23CD7A] PASSED: verified
# INFO - [user DC9CA1AC54BEE97BC4F2AA051EB6CF02] PASSED: verified
# INFO - [user DCDB40BBB398F92DBD9F6ABFE420C4B6] PASSED: verified
# INFO - [user DF1712CA573E96625477EF4A969BB819] PASSED: verified
# INFO - [user E0E6E07A87FEE810709097734D63CDC8] PASSED: verified
# INFO - [user E903C4F5B4A581405AE124E12CDA28E0] PASSED: verified
# INFO - [user E98BD2A2AFF876C71F2BE150B4E4B5F2] PASSED: verified
# INFO - [user EDAB30A6D7E94AFBF76495113B4A839D] PASSED: verified
# INFO - [user F26B9B8B90F2ECFE57C8AADBDA9B5D37] PASSED: verified
# INFO - [user F423E9B7B61EA54F6D9379FD83E0606E] PASSED: verified
# INFO - [user F9A55264CB8FFA786ADD87178D1DAD2F] PASSED: verified
# INFO - [worker 2] shutting down
# INFO - [worker 1] shutting down
# INFO - [worker 5] shutting down
# INFO - [worker 3] shutting down
# INFO - [worker 4] shutting down
# INFO - all user ids are ready

# %% [markdown]
# ## Data Extraction
#
# The suite then extracts disired information by matching several patterns from the raw HTML strings in an offline manner.
# Unlike the crawling modules, the implementation of extration components is order-insensitive.

# %%
with taDB(fn) as db:
    db.extract_hotel_info()
    db.extract_review_info()
    db.extract_user_info()
# Out:
# extracting hotel 566124...
# extracting user 4216644B2B3E5333E35A30565290DF74...
# extracting user 44C072E5D7CB641B6C74618532EE0C67...
# extracting user 471F5F614835BDAE44624ADCC5BC3179...
# extracting user 4F346C4C664117DE8D840F498F38806E...
# extracting user 546ACCC7FA3B724786513F49043ABE4F...
# extracting user 54F0A20ADAB6F11948BCE047DFB9F605...
# extracting user 5A434ACB51E8CE5FF2B4E68972C20F51...
# extracting user 5B09E3237D7B24CB450A534DBFBA02AA...
# extracting user 5D311C1A5C54D251F2EEDC8E79273CC3...
# extracting user 6BA070D60358CD1DA4CAD9D29BFF7CD1...
# extracting user 72C227ACF2158E2AFC461D91BA7B86ED...
# extracting user 75105453B9261F313D437E154646367C...
# extracting user 79E95D034C1E6EC625D350191185D00D...
# extracting user 7D5B2A809A82FAAFDDFECE414E2C13B5...
# extracting user 7FB95052A8FDC1458FA16F4063C3D4FF...
# extracting user 812AF6FA6D84E4A6EB7B6822E7943310...
# extracting user 83991B6C21929E9B62398A46DB9E8BF4...
# extracting user 83EAE255A3CB3B7261923F2AB68DB911...
# extracting user 841AC2C00AF29D506951CB9678D43474...
# extracting user 86B42A2102F20203772D0DD0EE0F5858...
# extracting user 871E2B6D2863474AD1406839E906E19F...
# extracting user 8C2AE9C2EBDF526C013F3C4B46A9D080...
# extracting user 8C2E786919CBDAED72EF110B38DAA178...
# extracting user 90F99D6B1FC3A1FD2E1AC52A97C0509E...
# extracting user 961813041BFA0419D5880E73EAEEF9DC...
# extracting user 9D2082EDCF3DC92961AECB77759150D2...
# extracting user B1A5B7467678224CF6FFBD87DA7D5E66...
# extracting user B79A8D783CEAC3DBE4FC7AC6618DC554...
# extracting user BA0B5797D5A342537EB070B8EF99A793...
# extracting user BB274CFD1EDFBD03176807FA6CF542BA...
# extracting user C122BF073E12846D0372A76B7E5CF43F...
# extracting user C34780BD8C16A26BB79BD04EFF6637F4...
# extracting user C45A2291956717B567989754E111C089...
# extracting user C4E4F4D3630AA153F0F0D38B8DF9DF7F...
# extracting user C5D7BCD24820A6877AC9CF929F49482F...
# extracting user C7F9CCF1CADBDDE2570AED7973927704...
# extracting user C943E71137CCFE899F068309DF9A2DCB...
# extracting user CD24804E5992917D21E46C80B62A41EA...
# extracting user CF5BDC137D67502744A58D0A18105E57...
# extracting user D4003973FB5F2F4175FAB8BCAD23CD7A...
# extracting user DC9CA1AC54BEE97BC4F2AA051EB6CF02...
# extracting user DCDB40BBB398F92DBD9F6ABFE420C4B6...
# extracting user DF1712CA573E96625477EF4A969BB819...
# extracting user E0E6E07A87FEE810709097734D63CDC8...
# extracting user E903C4F5B4A581405AE124E12CDA28E0...
# extracting user E98BD2A2AFF876C71F2BE150B4E4B5F2...
# extracting user EDAB30A6D7E94AFBF76495113B4A839D...
# extracting user F26B9B8B90F2ECFE57C8AADBDA9B5D37...
# extracting user F423E9B7B61EA54F6D9379FD83E0606E...
# extracting user F9A55264CB8FFA786ADD87178D1DAD2F...
# user extraction done.

# %% [markdown]
# That's it. Now you have your data ready in the local database. Enjoy!
